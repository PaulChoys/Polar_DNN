# %% [markdown]
# # N = 8 K = 4

# %% [markdown]
#     layer1 : 8
#     layer2 : 8
#     layer3 : 8
#     layer4 : 4

# %%
# epoch: 1024
# -- 0 -> 0.333852
# -- 1023 -> 0.250691
# cost: 0.224742
# Accuracy: 0.640625
# -----------------------------------------
# epoch: 4096
# -- 0 -> 0.219979
# -- 4095 -> 0.162257
# cost: 0.166111
# Accuracy: 0.734375
# -----------------------------------------
# epoch: 16384
# -- 0 -> 0.18448
# -- 10000 -> 0.130575
# cost: 0.0874613
# Accuracy: 0.859375
# -----------------------------------------
# epoch: 65536
# -- 0 -> 0.0879552
# -- 10000 -> 0.0716435
# -- 20000 -> 0.0784628
# -- 30000 -> 0.0485223
# -- 40000 -> 0.0351253
# -- 50000 -> 0.0179536
# -- 60000 -> 0.0644525
# cost: 0.0249136
# Accuracy: 0.96875
# -----------------------------------------
# epoch: 262144
# -- 0 -> 0.032342
# -- 10000 -> 0.0389958
# -- 20000 -> 0.00335504
# -- 30000 -> 0.0397942
# -- 40000 -> 0.0207653
# -- 50000 -> 0.0534032
# -- 60000 -> 0.0390825
# -- 70000 -> 0.0524014
# -- 80000 -> 0.0268719
# -- 90000 -> 0.0170355
# -- 100000 -> 0.00483888
# -- 110000 -> 0.0225223
# -- 120000 -> 0.00194247
# -- 130000 -> 0.0213757
# -- 140000 -> 0.0159104
# -- 150000 -> 0.0199989
# -- 160000 -> 0.00284484
# -- 170000 -> 0.018477
# -- 180000 -> 0.0421161
# -- 190000 -> 0.0171585
# -- 200000 -> 0.0258096
# -- 210000 -> 0.00437475
# -- 220000 -> 0.0130183
# -- 230000 -> 0.0231344
# -- 240000 -> 0.0231545
# -- 250000 -> 0.0317318
# -- 260000 -> 0.0104154
# cost: 0.0263578
# Accuracy: 1.0
# -----------------------------------------

# %% [markdown]
#     layer1 : 128
#     layer2 : 64
#     layer3 : 32
#     layer4 : 4

# %%
# epoch: 1024
# -- 0 -> 0.471064
# -- 1023 -> 0.442651
# cost: 0.405348
# Accuracy: 0.65625
# -----------------------------------------
# epoch: 4096
# -- 0 -> 0.390764
# -- 4095 -> 0.262467
# cost: 0.265327
# Accuracy: 0.765625
# -----------------------------------------
# epoch: 16384
# -- 0 -> 0.265625
# -- 10000 -> 0.0636244
# cost: 0.000626147
# Accuracy: 0.984375
# -----------------------------------------
# epoch: 65536
# -- 0 -> 0.00189149
# -- 10000 -> 0.000350422
# -- 20000 -> 8.88178e-16
# -- 30000 -> 0.0152597
# -- 40000 -> 3.11958e-08
# -- 50000 -> 4.84482e-11
# -- 60000 -> 0.00388975
# cost: 2.56684e-13
# Accuracy: 1.0
# -----------------------------------------
